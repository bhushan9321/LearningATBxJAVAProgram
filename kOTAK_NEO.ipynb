# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushan9321/LearningATBxJAVAProgram/blob/master/kOTAK_NEO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install "git+https://github.com/Kotak-Neo/Kotak-neo-api-v2.git@v2.0.1#egg=neo_api_client"
# Out:
# ...
#   Cloning https://github.com/Kotak-Neo/Kotak-neo-api-v2.git (to revision v2.0.1) to /tmp/pip-install-kdm565ff/neo-api-client_08c22b68a1494438a903700a41284e1c
#   Running command git clone --filter=blob:none --quiet https://github.com/Kotak-Neo/Kotak-neo-api-v2.git /tmp/pip-install-kdm565ff/neo-api-client_08c22b68a1494438a903700a41284e1c
#   Resolved https://github.com/Kotak-Neo/Kotak-neo-api-v2.git to commit 1533903cb5db1a50892223b404d753dbc8fba50e
#   Preparing metadata (setup.py) ... done
# ...

# %%
pip install --force-reinstall "git+https://github.com/Kotak-Neo/Kotak-neo-api-v2.git@v2.0.1#egg=neo_api_client"
# Out:
# ...
#   Cloning https://github.com/Kotak-Neo/Kotak-neo-api-v2.git (to revision v2.0.1) to /tmp/pip-install-5g0xu18l/neo-api-client_7a51e8b9f2ea4b4a85918dd26896896c
#   Running command git clone --filter=blob:none --quiet https://github.com/Kotak-Neo/Kotak-neo-api-v2.git /tmp/pip-install-5g0xu18l/neo-api-client_7a51e8b9f2ea4b4a85918dd26896896c
#   Resolved https://github.com/Kotak-Neo/Kotak-neo-api-v2.git to commit 1533903cb5db1a50892223b404d753dbc8fba50e
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 4.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 8.4 MB/s eta 0:00:00
# ...

# %%
import neo_api_client

# %%
from neo_api_client import NeoAPI

# %%
client = NeoAPI(environment='prod', access_token=None, neo_fin_key=None, consumer_key='7710b49d-f49f-43f7-bb8f-b2dc456f92d8')

# %%
client.totp_login(mobile_number="+919324221155", ucc="Y9601", totp='284957')
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..j6r3sNbBLfVbQS5p7gU4mBVJQp7spZaRT5yEXPkhVQMkx1Yuk-YUK8MagguS1kku8BREB6VOx89nLDJTcd2VOekICIZg06H1rUtyWUmJ0FDKbtPdYNansuDlhvL4cS_vM074q8MlHPzvswwlImmAsIkaDCpBGAhP4lgXQnkMrB6pP367osPL6Ta8CqLRBW7WZhzc6U8TJ6D5becMyblYFM1OsiJYCbAg_Po4oRdnh-Dc86Zi078S0vaD4Lz8NWVyRjWF9bcvTRt5cq4S78X2FlZoJ2yJiaTRQGsaIHP1y3RmvY55thbHWawz8CfZEpjPeyygbmsdHm0oJ7OO9Eg82w',
#   'sid': 'a7eea251-09c8-42c7-8ba5-03ef5689532f',
#   'rid': 'dea364ad-119f-4741-911c-3f97bfa1a7bb',
#   'hsServerId': '',
#   'isUserPwdExpired': False,
#   'ucc': 'Y9601',
#   'greetingName': 'BHUSHAN',
# ...

# %%
client.totp_validate(mpin="051092")
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9._clx1MDAwNlx1MDAwYlxydFx1MDAwMFx1MDAxMGIiLCJmZXRjaGNhY2hpbmdydWxlIjowLCJjYXRlZ29yaXNhdGlvbiI6IiJ9.GLCy3DnjN7ZyxwhPxycvPPLg2cYCFBHDIOVXY5zVvIvQLRFLF174Zvd2k2gqlt08hkWAzGF80YyF4lgXytZ7tpDGT8SrruHn2umsiQIHHtwar--iBGxhoi4YNImvE5kIod-Obmz0V6GIUKwd8f5rashrxdE04EbQkPyzjn19tg6EOTubpochnpIOeVTHSsXWG3yaFiIBLz-Szf9YlBfnJq7sCUBXP7ViMP8F-5ryfz8esHKYR3VCd1cddIRRh5XiHX_xpfEAs5j8SmV6dXP2d8fdh5WAG4Vk46DZ68cD-o7ifPDkxDZG2KHH3A5ZmutpV7CXELTjO2aTPax9tlOFlQ',
#   'sid': '065fe09a-61f3-4420-a0ee-2e335f1dc39b',
#   'rid': 'dea364ad-119f-4741-911c-3f97bfa1a7bb',
#   'baseUrl': 'https://e22.kotaksecurities.com',
#   'hsServerId': '',
#   'isUserPwdExpired': False,
# ...

# %%
client.place_order(
    exchange_segment="nse_cm",product="MIS",price="0",order_type="MKT",quantity="10",validity="DAY",trading_symbol="LT-EQ",transaction_type="B",amo="NO",disclosed_quantity="0",
    market_protection="0",
    pf="N",
    trigger_price="0",
    tag=None,
    scrip_token=None,
    square_off_type=None,
    stop_loss_type=None,
    stop_loss_value=None,
    square_off_value=None,
    last_traded_price=None,
    trailing_stop_loss=None,
    trailing_sl_value=None,
)
# Out:
# {'nOrdNo': '260201000000061', 'stat': 'Ok', 'stCode': 200}
